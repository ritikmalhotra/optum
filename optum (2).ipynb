# %%
import numpy as np
import pandas as pd
import glob
import os
os.chdir("C:\\Users\Shubham Rao\OneDrive\Desktop\optum")

# %%
imag1 = pd.read_csv("imaging_studies.csv")
imag1
# Out:
#                                        Id                  DATE  \
# 0    d3e49b38-7634-4416-879d-7bc68bf3e7df  2014-07-08T15:35:36Z
# 1    46baf530-4941-40ab-8219-685a08fd9086  2014-01-22T18:58:37Z
# 2    b8fb8a6e-a2f5-46c9-8b3f-a35aa982efcd  2001-12-01T02:08:27Z
# 3    10c8a016-4504-4653-bddf-2dd3610886c8  2004-07-03T20:46:46Z
# 4    4221534c-d379-4c6b-a22e-d7eae3fa2609  2017-02-08T08:42:44Z
# ..                                    ...                   ...
# 850  9148d80c-9ba5-4bcd-8c31-8eebb32d33d0  1988-03-25T17:27:52Z
# 851  904779de-bcc8-411e-88ec-92bacecfe43a  1989-03-20T17:27:52Z
# 852  cb3552e4-4959-4c4d-b8ba-36d71608e32e  1990-03-15T17:27:52Z
# 853  d5203a3f-75da-48a6-b750-8c5fa59ed657  1990-03-15T17:27:52Z
# 854  23337364-87f9-4c98-812d-eabd9abd8502  1990-03-15T17:27:52Z
#
#                                   PATIENT  \
# 0    b58731cc-2d8b-4c2d-b327-4cab771af3ef
# 1    2ffe9369-24e4-414b-8973-258fad09313a
# 2    86b97fc7-ae8f-4e0d-8e66-db68f36e7a76
# ...

# %%
allergies = pd.read_csv("allergies.csv")
allergies.drop(["STOP"],axis=1,inplace=True)
allergies
# Out:
#           START                               PATIENT  \
# 0    1982-10-25  76982e06-f8b8-4509-9ca3-65a99c8650fe
# 1    1982-10-25  76982e06-f8b8-4509-9ca3-65a99c8650fe
# 2    2002-01-25  71ba0469-f0cc-4177-ac70-ea07cb01c8b8
# 3    2002-01-25  71ba0469-f0cc-4177-ac70-ea07cb01c8b8
# 4    2002-01-25  71ba0469-f0cc-4177-ac70-ea07cb01c8b8
# ..          ...                                   ...
# 592  2000-01-03  e6ff4bf9-09c2-4976-aa84-cca142207cf8
# 593  2000-01-03  e6ff4bf9-09c2-4976-aa84-cca142207cf8
# 594  2000-01-03  e6ff4bf9-09c2-4976-aa84-cca142207cf8
# 595  2000-01-03  e6ff4bf9-09c2-4976-aa84-cca142207cf8
# 596  1915-09-12  13b9a676-7cfd-4b7c-bdb6-43ec52b7c919
#
#                                 ENCOUNTER       CODE              DESCRIPTION
# 0    b896bf40-8b72-42b7-b205-142ee3a56b55  300916003            Latex allergy
# 1    b896bf40-8b72-42b7-b205-142ee3a56b55  300913006        Shellfish allergy
# 2    7be1a590-4239-4826-9872-031327f3c368  419474003         Allergy to mould
# ...

# %%
careplans = pd.read_csv("careplans.csv")
careplans.drop(["STOP"],axis=1,inplace=True)
careplans
# Out:
#                                         Id       START  \
# 0     d2500b8c-e830-433a-8b9d-368d30741520  2010-01-23
# 1     07d9ddd8-dfa1-4e43-9bfe-39f63f4ace15  2011-05-13
# 2     a3bb6e99-3b99-44b3-974c-e230b4511b5c  2011-12-31
# 3     9f5284b7-425a-486a-b36e-ab818c018f2f  2016-12-29
# 4     47ede16c-c216-4f81-a16b-0e858de9cdc3  2017-01-22
# ...                                    ...         ...
# 3478  5998d466-9922-4a35-9277-7a902352ce48  1983-09-08
# 3479  3de3b598-ca98-4b98-947a-34e3e86630e6  1984-09-23
# 3480  6f02c458-e04f-429d-99ce-72626d87952d  1987-09-27
# 3481  243de451-1e53-40fc-b4ae-e0ea730e4a0d  1990-03-15
# 3482  f7b75d85-fd8f-4c1b-bcfd-775e63a12490  1957-08-25
#
#                                    PATIENT  \
# 0     034e9e3b-2def-4559-bb2a-7850888ae060
# 1     10339b10-3cd1-4ac3-ac13-ec26728cb592
# 2     f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
# 3     034e9e3b-2def-4559-bb2a-7850888ae060
# 4     10339b10-3cd1-4ac3-ac13-ec26728cb592
# ...

# %%
conditions = pd.read_csv("conditions.csv")
conditions.drop(["STOP"],axis=1,inplace=True)
conditions
# Out:
#            START                               PATIENT  \
# 0     2001-05-01  1d604da9-9a81-4ba9-80c2-de3375d59b40
# 1     2011-08-09  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae
# 2     2011-11-16  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae
# 3     2011-05-13  10339b10-3cd1-4ac3-ac13-ec26728cb592
# 4     2011-02-06  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
# ...          ...                                   ...
# 8371  1984-12-29  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 8372  1988-08-24  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 8373  2009-08-08  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 8374  2010-11-18  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 8375  2012-04-23  fc817953-cc8b-45db-9c85-7c0ced8fa90d
#
#                                  ENCOUNTER       CODE  \
# 0     8f104aa7-4ca9-4473-885a-bba2437df588   40055000
# 1     9d35ec9f-352a-4629-92ef-38eae38437e7  444814009
# 2     ae7555a9-eaff-4c09-98a7-21bc6ed1b1fd  195662009
# 3     e1ab4933-07a1-49f0-b4bd-05500919061d   10509002
# ...

# %%
devices = pd.read_csv("devices.csv")
devices.drop(["STOP"],axis=1,inplace=True)
devices
# Out:
#                    START                               PATIENT  \
# 0   2001-07-04T08:42:44Z  d49f748f-928d-40e8-92c8-73e4c5679711
# 1   2010-10-24T05:28:51Z  e05dd037-e45f-434a-946d-5c9076a2f596
# 2   2017-06-04T11:11:47Z  0f5646bc-a156-4ec0-9252-5b592e3d3184
# 3   1989-01-17T18:12:03Z  44c8b4c8-4457-4ba0-94b6-285ef327a249
# 4   1973-07-19T04:25:46Z  89752052-a38b-45f0-a590-3950bbb67bec
# ..                   ...                                   ...
# 73  1997-01-27T14:31:51Z  9bebd912-a12b-4a83-a02c-f510587246df
# 74  1994-02-08T13:04:22Z  9c4c1885-35af-48b9-a09f-4ea448d40d75
# 75  2018-11-04T07:02:15Z  2f76733b-933c-4cc5-aea2-53799158c8cc
# 76  1955-02-01T13:04:22Z  87f05059-de42-4630-a35b-edb53d880640
# 77  1988-05-17T13:04:22Z  023a7d29-32b3-4db5-89c8-b88bd7582ec0
#
#                                ENCOUNTER       CODE  \
# 0   2500b8bd-dc98-44ef-a252-22dc4f81d61b   72506001
# 1   83cda5b1-4653-4327-a81c-14c4af434e95   72506001
# ...

# %%
encounters = pd.read_csv("encounters.csv")
encounters.drop(["STOP","REASONCODE","REASONDESCRIPTION"],axis=1,inplace=True)
encounters
# Out:
#                                          Id                 START  \
# 0      d0c40d10-8d87-447e-836e-99d26ad52ea5  2010-01-23T17:45:28Z
# 1      e88bc3a9-007c-405e-aabc-792a38f4aa2b  2012-01-23T17:45:28Z
# 2      8f104aa7-4ca9-4473-885a-bba2437df588  2001-05-01T15:02:18Z
# 3      b85c339a-6076-43ed-b9d0-9cf013dec49d  2011-07-28T15:02:18Z
# 4      dae2b7cb-1316-4b78-954f-fa610a6c6d0e  2010-07-27T12:58:08Z
# ...                                     ...                   ...
# 53341  bd3bfc3c-4f52-4d9c-aa01-60a084b2ddcd  2015-06-20T17:27:52Z
# 53342  59727285-d30f-44e2-bcda-eac21ce07269  2016-06-25T17:27:52Z
# 53343  957b13d5-49fa-4518-8c25-6eaa45e6a7d1  2017-07-01T17:27:52Z
# 53344  5529a0d5-a24c-42b4-a32a-729e4d1f19ef  2018-07-07T17:27:52Z
# 53345  1306d180-d887-4286-b940-9a6a2425cf93  2019-07-13T17:27:52Z
#
#                                     PATIENT  \
# 0      034e9e3b-2def-4559-bb2a-7850888ae060
# 1      034e9e3b-2def-4559-bb2a-7850888ae060
# ...

# %%
immunizations = pd.read_csv("immunizations.csv")
immunizations
# Out:
#                        DATE                               PATIENT  \
# 0      2010-07-27T12:58:08Z  10339b10-3cd1-4ac3-ac13-ec26728cb592
# 1      2010-11-20T03:04:34Z  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
# 2      2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 3      2011-11-26T03:04:34Z  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
# 4      2011-07-28T15:02:18Z  1d604da9-9a81-4ba9-80c2-de3375d59b40
# ...                     ...                                   ...
# 15473  2011-05-28T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 15474  2012-06-02T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 15475  2013-06-08T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 15476  2014-06-14T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 15477  2015-06-20T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
#
#                                   ENCOUNTER  CODE  \
# 0      dae2b7cb-1316-4b78-954f-fa610a6c6d0e   140
# 1      7ff86631-0378-4bfc-92ce-1edd697eb18e   140
# ...

# %%
medications = pd.read_csv("medications.csv")
medications.drop(["STOP","REASONCODE","REASONDESCRIPTION"],axis=1,inplace=True)
medications
# Out:
#                       START                               PATIENT  \
# 0      2010-05-05T00:26:23Z  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae
# 1      2011-04-30T00:26:23Z  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae
# 2      2012-04-24T00:26:23Z  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae
# 3      2011-05-13T12:58:08Z  10339b10-3cd1-4ac3-ac13-ec26728cb592
# 4      2011-12-08T15:02:18Z  1d604da9-9a81-4ba9-80c2-de3375d59b40
# ...                     ...                                   ...
# 42984  1983-09-08T17:27:52Z  fca3178e-fb68-41c3-8598-702d3ca68b96
# 42985  1984-09-23T17:27:52Z  fca3178e-fb68-41c3-8598-702d3ca68b96
# 42986  1987-09-27T17:27:52Z  fca3178e-fb68-41c3-8598-702d3ca68b96
# 42987  1987-09-27T17:27:52Z  fca3178e-fb68-41c3-8598-702d3ca68b96
# 42988  1990-03-15T17:27:52Z  fca3178e-fb68-41c3-8598-702d3ca68b96
#
#                                       PAYER  \
# 0      b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1      b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# ...

# %%
observations = pd.read_csv("observations.csv")
observations.drop(["UNITS"],axis=1,inplace=True)
observations
# Out:
#                         DATE                               PATIENT  \
# 0       2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 1       2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 2       2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 3       2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 4       2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# ...                      ...                                   ...
# 299692  2015-09-05T16:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 299693  2016-09-05T16:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 299694  2017-09-05T16:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 299695  2018-09-05T16:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 299696  2019-09-05T16:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
#
#                                    ENCOUNTER     CODE  \
# 0       e88bc3a9-007c-405e-aabc-792a38f4aa2b   8302-2
# ...

# %%
organizations = pd.read_csv("organizations.csv")
organizations.drop(["STATE","ZIP","LAT","LON","PHONE"],axis=1,inplace=True)
organizations
# Out:
#                                         Id  \
# 0     ef58ea08-d883-3957-8300-150554edc8fb
# 1     69176529-fd1f-3b3f-abce-a0a3626769eb
# 2     5e765f2b-e908-3888-9fc7-df2cb87beb58
# 3     f1fbcbfb-fcfa-3bd2-b7f4-df20f1b3c3a4
# 4     e002090d-4e92-300e-b41e-7d1f21dee4c6
# ...                                    ...
# 1114  700056a6-3aea-3efd-8423-a9acbd38a5ea
# 1115  308b5efa-a9c2-3728-b1ff-d29c5f060731
# 1116  bbf934c6-faad-3483-a1d2-d2ecb693a0e2
# 1117  90cf148c-69ed-3d33-aa86-b509c6b0b25f
# 1118  1aedcb45-c507-3ad0-9010-6583d264ae72
#
#                                                    NAME  \
# 0                         HEALTHALLIANCE HOSPITALS  INC
# 1                                 MOUNT AUBURN HOSPITAL
# 2                              STURDY MEMORIAL HOSPITAL
# 3                             LAWRENCE GENERAL HOSPITAL
# 4                             CAMBRIDGE HEALTH ALLIANCE
# ...                                                 ...
# ...

# %%
patients = pd.read_csv("patients.csv")
patients.drop(["DEATHDATE","DRIVERS","PASSPORT","PREFIX","SUFFIX","MAIDEN","MARITAL","LAT","LON","COUNTY","ZIP"],axis=1,inplace=True)
patients
# Out:
#                                         Id   BIRTHDATE          SSN  \
# 0     1d604da9-9a81-4ba9-80c2-de3375d59b40  1989-05-25  999-76-6866
# 1     034e9e3b-2def-4559-bb2a-7850888ae060  1983-11-14  999-73-5361
# 2     10339b10-3cd1-4ac3-ac13-ec26728cb592  1992-06-02  999-27-3385
# 3     8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  1978-05-27  999-85-4926
# 4     f5dcd418-09fe-4a2f-baa0-3da800bd8c3a  1996-10-18  999-60-7372
# ...                                    ...         ...          ...
# 1166  023a7d29-32b3-4db5-89c8-b88bd7582ec0  1922-02-14  999-60-9291
# 1167  1fc8dafd-90e5-44d6-9179-81156c0ea083  1977-08-08  999-29-3501
# 1168  6d048a56-edb8-4f29-891d-7a84d75a8e78  1914-09-05  999-60-2184
# 1169  fca3178e-fb68-41c3-8598-702d3ca68b96  1914-09-05  999-48-3257
# 1170  fc817953-cc8b-45db-9c85-7c0ced8fa90d  1914-09-05  999-72-8988
#
#                 FIRST           LAST   RACE    ETHNICITY GENDER  \
# 0     José Eduardo181       Gómez206  white     hispanic      M
# ...

# %%
payer_transitions = pd.read_csv("payer_transitions.csv")
payer_transitions.drop(["OWNERSHIP"],axis=1,inplace=True)
payer_transitions
# Out:
#                                    PATIENT  START_YEAR  END_YEAR  \
# 0     1d604da9-9a81-4ba9-80c2-de3375d59b40        1989      1998
# 1     034e9e3b-2def-4559-bb2a-7850888ae060        1983      2001
# 2     8d4c4326-e9de-4f45-9a4c-f8c36bff89ae        1978      1995
# 3     8d4c4326-e9de-4f45-9a4c-f8c36bff89ae        1996      1996
# 4     8d4c4326-e9de-4f45-9a4c-f8c36bff89ae        1997      1999
# ...                                    ...         ...       ...
# 3796  fc817953-cc8b-45db-9c85-7c0ced8fa90d        1941      1943
# 3797  fc817953-cc8b-45db-9c85-7c0ced8fa90d        1944      1944
# 3798  fc817953-cc8b-45db-9c85-7c0ced8fa90d        1945      1949
# 3799  fc817953-cc8b-45db-9c85-7c0ced8fa90d        1950      1950
# 3800  fc817953-cc8b-45db-9c85-7c0ced8fa90d        1951      1979
#
#                                      PAYER
# 0     b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1     6e2f1a2d-27bd-3701-8d08-dae202c58632
# 2     7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a
# ...

# %%
payers = pd.read_csv("payers.csv")
payers.drop(["CITY","STATE_HEADQUARTERED","ADDRESS","ZIP","PHONE"],axis=1,inplace=True)
payers
# Out:
#                                      Id                    NAME  \
# 0  b3221cfc-24fb-339e-823d-bc4136cbc4ed           Dual Eligible
# 1  7caa7254-5050-3b5e-9eae-bd5ea30e809c                Medicare
# 2  7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a                Medicaid
# 3  d47b3510-2895-3b70-9897-342d681c769d                  Humana
# 4  6e2f1a2d-27bd-3701-8d08-dae202c58632  Blue Cross Blue Shield
# 5  5059a55e-5d6e-34d1-b6cb-d83d16e57bcf        UnitedHealthcare
# 6  4d71f845-a6a9-3c39-b242-14d25ef86a8d                   Aetna
# 7  047f6ec3-6215-35eb-9608-f9dda363a44c            Cigna Health
# 8  42c4fca7-f8a9-3cd1-982a-dd9751bf3e2a                  Anthem
# 9  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76            NO_INSURANCE
#
#    AMOUNT_COVERED  AMOUNT_UNCOVERED      REVENUE  COVERED_ENCOUNTERS  \
# 0       141676.87         119449.83    1305000.0                 907
# 1      4756720.13         890394.37    7122250.0               11072
# ...

# %%
procedures = pd.read_csv("procedures.csv")
procedures.drop(["REASONCODE","REASONDESCRIPTION"],axis=1,inplace=True)
procedures
# Out:
#                        DATE                               PATIENT  \
# 0      2011-04-30T00:26:23Z  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae
# 1      2010-07-27T12:58:08Z  10339b10-3cd1-4ac3-ac13-ec26728cb592
# 2      2010-11-20T03:04:34Z  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
# 3      2011-02-07T03:04:34Z  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
# 4      2011-04-19T03:04:34Z  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
# ...                     ...                                   ...
# 34976  2010-05-22T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 34977  2013-06-08T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 34978  2015-06-20T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 34979  2017-07-01T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
# 34980  2019-07-13T17:27:52Z  fc817953-cc8b-45db-9c85-7c0ced8fa90d
#
#                                   ENCOUNTER       CODE  \
# 0      6aa37300-d1b4-48e7-a2f8-5e0f70f48f38  169553002
# 1      dae2b7cb-1316-4b78-954f-fa610a6c6d0e  430193006
# ...

# %%
providers = pd.read_csv("providers.csv")
providers.drop(["STATE","ZIP","LAT","LON"],axis=1,inplace=True)
providers
# Out:
#                                         Id  \
# 0     3421aa75-dec7-378d-a9e0-0bc764e4cb0d
# 1     c9b3c857-2e24-320c-a79a-87b8a60de63c
# 2     0359f968-d1a6-30eb-b1cc-e6cc0b4d3513
# 3     446d1609-858f-3a54-8a52-0c4eacedd00e
# 4     e6283e46-fd81-3611-9459-0edb1c3da357
# ...                                    ...
# 5850  259f5953-cd6f-3c3d-a47b-257882dffb4f
# 5851  cb868a81-474c-3547-bf2d-d88a03795bb5
# 5852  d580fc85-4685-3e51-aad5-e47bebd98b01
# 5853  5718012f-98aa-3971-ad2e-bd42da8625ea
# 5854  65eab060-ae31-3bfe-84f0-c2ed82195f26
#
#                               ORGANIZATION                    NAME GENDER  \
# 0     ef58ea08-d883-3957-8300-150554edc8fb       Tomas436 Sauer652      M
# 1     69176529-fd1f-3b3f-abce-a0a3626769eb   Suzette512 Monahan736      F
# 2     5e765f2b-e908-3888-9fc7-df2cb87beb58   Gaynell126 Streich926      F
# 3     f1fbcbfb-fcfa-3bd2-b7f4-df20f1b3c3a4  Patricia625 Salgado989      F
# ...

# %%
supplies = pd.read_csv("supplies.csv")
supplies.count()
# Out:
# DATE           0
# PATIENT        0
# ENCOUNTER      0
# CODE           0
# DESCRIPTION    0
# QUANTITY       0
# dtype: int64

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
# Out:
# C:\Users\Shubham Rao\Anaconda3\envs\tensorflow_cpu\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (0,5,6,8,9,10,11,16,17,18,20,21,22,24,25,26,29,30,33,34,36,37,38,39,40,41,42,43,45,46,47,50,52,54,55,56,57,58,60,61,62,63,66,67,73,75,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\Shubham Rao\Anaconda3\envs\tensorflow_cpu\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
allfile = pd.read_csv("combined_csv.csv",low_memory=False)
allfile["PATIENT"].dropna(inplace=True)
allfile["ENCOUNTERCLASS"].dropna(inplace=True)
len(allfile["ENCOUNTERCLASS"])
# Out:
# 106692

# %%
os.chdir("C:\\Users\Shubham Rao\Downloads")
df6 = pd.read_csv("optum_withoutencounter.csv")    
df6
df6.drop(["PATIENT","Unnamed: 0","OBSERVATION_UNITS","SOP_CODE","MODALITY_CODE","PAYER"],axis=1,inplace=True)
df6
# Out:
#       ALLERGIES_CODE GENDER       CITY          STATE            COUNTY  \
# 0        300916003.0      F     Boston  Massachusetts    Suffolk County
# 1        419474003.0      F    Ashland  Massachusetts  Middlesex County
# 2        419474003.0      F     Boston  Massachusetts    Suffolk County
# 3        300916003.0      F    Ashland  Massachusetts  Middlesex County
# 4        419474003.0      M  Lynnfield  Massachusetts      Essex County
# ...              ...    ...        ...            ...               ...
# 1166             NaN      F  Cambridge  Massachusetts  Middlesex County
# 1167             NaN      M    Beverly  Massachusetts      Essex County
# 1168             NaN      F    Norwood  Massachusetts    Norfolk County
# 1169             NaN      F    Norwood  Massachusetts    Norfolk County
# 1170             NaN      F    Norwood  Massachusetts    Norfolk County
#
#       HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE  CAREPLANS_CODE  \
# ...

# %%
from sklearn import preprocessing   
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
df6['GENDER']= label_encoder.fit_transform(df6['GENDER']) 
df6['CITY']= label_encoder.fit_transform(df6['CITY'])
df6['STATE']= label_encoder.fit_transform(df6['STATE']) 
df6['COUNTY']= label_encoder.fit_transform(df6['COUNTY'])
#df['OBSERVATION_UNITS']= label_encoder.fit_transform(df['OBSERVATION_UNITS']) 
df6.ALLERGIES_CODE.fillna(df6.ALLERGIES_CODE.median(),inplace=True)
df6.DEVICES_CODE.fillna(df6.DEVICES_CODE.median(),inplace=True)
df6.REASONCODE_PROCEDURE.fillna(df6.REASONCODE_PROCEDURE.median(),inplace=True)
df6.MEDICATION_REASONCODE.fillna(df6.MEDICATION_REASONCODE.median(),inplace=True)
df6.MEDICATION_BASECOST.fillna(df6.MEDICATION_BASECOST.median(),inplace=True)
df6.MEDICATION_PAYERCOVERAGE.fillna(df6.MEDICATION_PAYERCOVERAGE.median(),inplace=True)
df6.DISPENSES.fillna(df6.DISPENSES.median(),inplace=True)
df6.BODYSITE_CODE.fillna(df6.BODYSITE_CODE.median(),inplace=True)
df6.MEDICATION_TOTALCOST.fillna(df6.MEDICATION_TOTALCOST.median(),inplace=True)
df6.MEDICATION_CODE.fillna(df6.MEDICATION_CODE.median(),inplace=True)
#df.MEDICATION_BASECOST.fillna(df.MEDICATION_BASECOST.median(),inplace=True)
df6
# Out:
#       ALLERGIES_CODE  GENDER  CITY  STATE  COUNTY  HEALTHCARE_EXPENSES  \
# 0        300916003.0       0    24      0      12            779464.29
# 1        419474003.0       0    10      0       8            268920.58
# 2        419474003.0       0    24      0      12             10057.19
# 3        300916003.0       0    10      0       8            499730.64
# 4        419474003.0       1   113      0       4            718679.10
# ...              ...     ...   ...    ...     ...                  ...
# 1166     419474003.0       0    33      0       8           1622314.87
# 1167     419474003.0       1    21      0       4            979724.25
# 1168     419474003.0       0   154      0      10           1560540.35
# 1169     419474003.0       0   154      0      10           1375833.47
# 1170     419474003.0       0   154      0      10           1510158.34
#
#       HEALTHCARE_COVERAGE  CAREPLANS_CODE  CONDITIONS_CODE  DEVICES_CODE  ...  \
# ...

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
# create datasets
y = df6.REASONCODE_PROCEDURE
df6.drop(["REASONCODE_PROCEDURE"],axis=1,inplace=True)
X = df6
# define model
model =LinearRegression()
# fit model
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-68897224ea07> in <module>
#       9 model =LinearRegression()
#      10 # fit model
# ---> 11 model.fit(X, y)
#
# C:\Users\Shubham Rao\Anaconda3\envs\tensorflow_cpu\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...
